# %%
import time
from selenium import webdriver
import chromedriver_binary
import pandas as pd
from IPython.core.display import display

url = "https://www.facebook.com/login/device-based/regular/login/?login_attempt=1&amp%3Blwv=101"
email_address = 'email_address'
password = 'password'

plofiles = []
urls = []

driver = webdriver.Chrome()
driver.get(url)
time.sleep(5)
userNameField = driver.find_element_by_xpath("//*[@id='email']")
userNameField.send_keys(email_address)

passwordField = driver.find_element_by_xpath("//*[@id='pass']")
passwordField.send_keys(password)

submitButton = driver.find_element_by_xpath("//*[@id='loginbutton']")
submitButton.click()

for a in driver.find_elements_by_class_name('profileLink'):
    plofiles.append(a.text)
    urls.append(a.get_attribute('href'))
    
df = pd.DataFrame.from_dict({"name": plofiles, "url": urls})
display(df)

time.sleep(5)
driver.quit()
# Out:
#              name                                                url
# 0           玉木 春那  https://www.facebook.com/profile.php?id=100012...
# 1            温泉ラボ  https://www.facebook.com/%E6%B8%A9%E6%B3%89%E3...
# 2           石口 茉季  https://www.facebook.com/maki.ishiguchi?__tn__...
# 3  Ryosuke Miichi  https://www.facebook.com/ryosuke.miichi?__tn__...
# 4   Momoko Iijima  https://www.facebook.com/profile.php?id=100006...
# 5        Le Monde  https://www.facebook.com/lemonde.fr/?__tn__=kC...
# 6           山口 和也  https://www.facebook.com/kazy1973?__tn__=%2Cdl...
# 7           羽倉 彬史  https://www.facebook.com/akifumi.hagura?__tn__...
# 8           矢口 真実  https://www.facebook.com/masamin.min?__tn__=%2...
