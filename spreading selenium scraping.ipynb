# %%
import time
from selenium import webdriver
import chromedriver_binary
from selenium.webdriver.chrome.options import Options
import pandas as pd
from IPython.core.display import display

url = "http://spreading.starfree.jp/wp-login.php?loggedout=true"
email_address = 'ballroom.love.z@gmail.com'
password = 'XhXI7mT8rTWO%zZx'

title_list = []
link_list = []
text_list = []
author_list = []

options = Options()
options.add_argument('--headless')
driver = webdriver.Chrome(chrome_options=options)
driver.get(url)
time.sleep(5)
userNameField = driver.find_element_by_xpath("//*[@id='user_login']")
userNameField.send_keys(email_address)

passwordField = driver.find_element_by_xpath("//*[@id='user_pass']")
passwordField.send_keys(password)

submitButton = driver.find_element_by_xpath("//*[@id='wp-submit']")
submitButton.click()

siteButton = driver.find_element_by_xpath("//*[@id='wp-admin-bar-site-name']/a")
siteButton.click()

for a in driver.find_elements_by_class_name('hc'):
    title_list.append(a.text)
    link_list.append(a.get_attribute('href'))

page_Buttom = driver.find_element_by_xpath("/html/body/div[4]/main/div[2]/a[1]")
page_Buttom.click()

for c in driver.find_elements_by_class_name('hc'):
    title_list.append(c.text)
    link_list.append(c.get_attribute('href'))


for href in link_list:
    driver.get(href)
    b = driver.find_element_by_class_name('content')
    text_list.append(len(b.text))
    w = driver.find_element_by_class_name('profile__name')
    author_list.append(w.text.replace('Author：','').replace('投稿一覧',''))


        
        
        
my_df = pd.DataFrame.from_dict({'title': title_list,'文字数':text_list,'記者': author_list, "link":link_list })
my_df
# Out:
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:19: DeprecationWarning: use options instead of chrome_options
#                                                 title   文字数                記者  \
# 0                     非公開: スペイン南部「グラナダ」「コルドバ」「ミハス」旅日記  1972       sekine_yui
# 1                               非公開: 渋谷ハロウィンを心理学で見てみた  2228   okazaki_yurika
# 2                               非公開: ＜WEB初心者向け＞CMSとは？  1345            川口 稜太
# 3                               非公開: RPAについて学生が説明してみる  2320           矢部 久仁人
# 4                    非公開: ＜WEB初心者向け＞　ドメインって何？サーバーって何？  1367            川口 稜太
# 5                           非公開: ＜WEB初心者向け＞UI/UXってなに？  1394            川口 稜太
# 6                      非公開: セルフマーケティング~マーケティングを活用しよう～  1745            加藤今日子
# 7                                       非公開: SEOってなに？   954             村山 駿
# 8              非公開: デキる営業マンは競馬予想が得意！？　〜競馬とビジネスの相関性とは～  1529             Sera
# 9                         非公開: 【働き方】週5日、1日8時間労働は普遍的か？  1065             ikko
# 10                             非公開: 営業は、個人戦ではない、チーム戦だ   777   okazaki_yurika
# 11                                  メタ認知とかいうやつをやっつける！   972   tadokoro_marin
# 12  非公開: 明日から使える！google spreadsheetsでビジネス統計学！③~重回帰...  2418  tokizawa_hayato
# 13  非公開: 明日から使える！google spreadsheetsでビジネス統計学②~goog...   677  tokizawa_hayato
# 14       非公開: 明日から使える！google spreadsheetでビジネス統計学①～導入～   965  tokizawa_hayato
# 15  非公開: 【フェミニズム ×男子学生】エマ・ワトソンに惹かれて読んだ記事で思う、向かうべき真...   903             Sera
#
#                                                  link
# 0   http://spreading.starfree.jp/2018/11/15/post-650/
# 1   http://spreading.starfree.jp/2018/11/13/post-643/
# 2   http://spreading.starfree.jp/2018/11/09/post-554/
# 3   http://spreading.starfree.jp/2018/11/08/post-563/
# 4   http://spreading.starfree.jp/2018/11/01/post-518/
# 5      http://spreading.starfree.jp/2018/10/30/ui-ux/
# 6   http://spreading.starfree.jp/2018/10/30/post-355/
# 7   http://spreading.starfree.jp/2018/10/26/post-403/
# 8   http://spreading.starfree.jp/2018/10/24/post-334/
# 9   http://spreading.starfree.jp/2018/10/24/post-325/
# 10  http://spreading.starfree.jp/2018/10/22/post-305/
# 11  http://spreading.starfree.jp/2018/10/21/post-123/
# 12  http://spreading.starfree.jp/2018/10/20/post-149/
# 13  http://spreading.starfree.jp/2018/10/20/post-186/
# 14  http://spreading.starfree.jp/2018/10/20/post-127/
# 15   http://spreading.starfree.jp/2018/10/18/post-68/
